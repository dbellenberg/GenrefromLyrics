# %%
import pandas as pd
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import string

import nltk
from nltk.corpus import stopwords

# %%
df = pd.read_pickle('/work/NLP_Project/GenreFromLyricsShared/cleaned_df/df_cleaned_engl.pkl')

# %%
df
# Out:
#                                                      title      tag
# 0                                                Killa Cam      rap  \
# 1                                               Can I Live      rap
# 2                                        Forgive Me Father      rap
# 3                                             Down and Out      rap
# 4                                                   Fly In      rap
# ...                                                    ...      ...
# 5913405                                              FÖRBI      pop
# 5913406                                    Raise Our Hands      pop
# 5913408  JokAir - Big Drip ft. ARÓN  LineMa Traducción ...      rap
# 5913409                                         New Number  country
# 5913410                                               Gone      rap
#
#                                 artist  year
# 0                              Cam'ron  2004  \
# 1                                JAY-Z  1996
# 2                             Fabolous  2003
# 3                              Cam'ron  2004
# 4                            Lil Wayne  2005
# ...                                ...   ...
# 5913405   Noah Wiking & Hugo Nordquist  2022
# 5913406       Culture Code, Pag & Mylo  2016
# 5913408  Genius Traducciones al Espaol  2022
# 5913409              Alana Springsteen  2022
# 5913410                           VAPO  2022
#
#                                                     lyrics       id language
# 0        [Chorus: Opera Steve & Cam'ron]\nKilla Cam, Ki...        1       en
# 1        [Produced by Irv Gotti]\n\n[Intro]\nYeah, hah,...        3       en
# 2        Maybe cause I'm eatin\nAnd these bastards fien...        4       en
# 3        [Produced by Kanye West and Brian Miller]\n\n[...        5       en
# 4        [Intro]\nSo they ask me\n"Young boy\nWhat you ...        6       en
# ...                                                    ...      ...      ...
# 5913405                                                TBD  7882844       en
# 5913406  [Verse 1]\nHere our purpose feels alive\nWe ar...  7882845       en
# 5913408                                     [Instrumental]  7882847       en
# 5913409  [Verse 1]\nYou need a new number, one that ain...  7882848       en
# 5913410                                     [Instrumental]  7882849       en
#
# [4042601 rows x 7 columns]

# %%
df = df.drop(['language'], axis=1)

# %%
#calculate number of words in lyrics
df['lyrics_word_count'] = df['lyrics'].apply(lambda x: len(str(x).split()))

# %%
#filtering df by length of lyrics and timeframe
#there are many lengthy lyric counts - we do not want these as many are spoken word or authored content. many songs with less 
df = df[(df['lyrics_word_count'] < 5000)]
df = df[(df['lyrics_word_count'] > 25)]
df = df[(df['year'] >= 1960) & (df['year'] <= 2023)]

# %%
#initial preprocessing steps
#step 1 - remove [] and anything inbetween, \n and so on

df['lyrics'] = df['lyrics'].str.replace('\n', ' ') 
df['lyrics'] = df['lyrics'].str.replace('\[.*?\]', '', regex=True) 
punctuation = string.punctuation  # This string contains !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~
# Remove punctuation from the lyrics
df['lyrics'] = df['lyrics'].str.replace('['+punctuation+']', '', regex=True)

# %%
df
# Out:
#                              title      tag                    artist  year
# 0                        Killa Cam      rap                   Cam'ron  2004  \
# 1                       Can I Live      rap                     JAY-Z  1996
# 2                Forgive Me Father      rap                  Fabolous  2003
# 3                     Down and Out      rap                   Cam'ron  2004
# 4                           Fly In      rap                 Lil Wayne  2005
# ...                            ...      ...                       ...   ...
# 5913399  Everything Is Alright Now      pop             Chuck Bernard  2013
# 5913401                 White Lies      pop                  ElementD  2019
# 5913403                      Ocean      pop                   Effemar  2022
# 5913406            Raise Our Hands      pop  Culture Code, Pag & Mylo  2016
# 5913409                 New Number  country         Alana Springsteen  2022
#
#                                                     lyrics       id
# 0         Killa Cam Killa Cam Cam Killa Cam Killa Cam K...        1  \
# 1           Yeah hah yeah RocAFella We invite you to so...        3
# 2        Maybe cause Im eatin And these bastards fiend ...        4
# 3           Ugh Killa Baby Kanye this that 1970s Heron ...        5
# 4         So they ask me Young boy What you gon do the ...        6
# ...                                                    ...      ...
# 5913399  Everything is alright now Oh yes baby Everythi...  7882838
# 5913401   Half truth and half you Didnt we say were thr...  7882840
# 5913403   Dance for me now Keeping yourself moving Your...  7882842
# 5913406   Here our purpose feels alive We are more than...  7882845
# 5913409   You need a new number one that aint burned in...  7882848
#
#          lyrics_word_count
# 0                      762
# 1                      548
# 2                      574
# 3                      760
# 4                      432
# ...                    ...
# 5913399                 63
# 5913401                171
# 5913403                166
# 5913406                184
# 5913409                293
#
# [3315185 rows x 7 columns]

# %%
df.sample(5)
# Out:
#                       title   tag          artist  year
# 1233602  Look At Me I’m You   pop    Blossom Toes  1967  \
# 4101982           Maljaande   pop         Tristan  2019
# 4877303           Cheeseboy   rap  Adam Ford (US)  2021
# 233953    Lames in the Game   rap       Hell Rell  2013
# 2938855           Whirlpool  rock  My Dad Is Dead  1989
#
#                                                     lyrics       id
# 1233602  Look at me Im you look at me Im you  Well well...  1552256  \
# 4101982   I know we are safe here But somehow I choose ...  5595453
# 4877303   It aint being easy being cheesy   I’m like pl...  6571833
# 233953   Intro The business is entertainment and what e...   278078
# 2938855  Shes got fists the size of the state of New Yo...  4138694
#
#          lyrics_word_count
# 1233602                255
# 4101982                222
# 4877303                336
# 233953                 676
# 2938855                208

# %%
avg_lyric_length_by_genre = df.groupby('tag')['lyrics_word_count'].mean()
avg_lyric_length_by_genre
# Out:
# tag
# country    231.952400
# pop        228.394698
# rap        432.536710
# rb         307.385275
# rock       203.557676
# Name: lyrics_word_count, dtype: float64

# %%
avg_lyric_length_by_genre.plot(kind='bar')
plt.title('Average Lyric Length by Genre')
plt.xlabel('Genre')
plt.ylabel('Average Lyric Length')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df['tag'].value_counts().plot(kind='bar')
plt.title('Genre Distribution')
plt.xlabel('Tag/Genre')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(10, 10))  # Width=15, height=10
df['year'].value_counts().sort_index().plot(kind='bar')
plt.title('Number of Songs by Year')
plt.xlabel('Year')
plt.ylabel('Count')
plt.show()

# %%
df['lyrics_word_count'].plot(kind='hist', rwidth=0.8, bins=30)
plt.title('Distribution of Word Count in Lyrics')
plt.xlabel('Word Count')
plt.ylabel('Frequency')
plt.show()

# %%
#preprocessing part 2

#lowercase everything
df['lyrics'] = df['lyrics'].str.lower()

#remove the words 'chorus' and 'verse'
df['lyrics'] = df['lyrics'].str.replace('chorus', '')
df['lyrics'] = df['lyrics'].str.replace('verse', '')

# %%
#preprocessing part 3 

#remove stopwords 


nltk.download('stopwords')  # download the stopwords from NLTK

stop = stopwords.words('english')

df['lyrics'] = df['lyrics'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop)]))
# Out:
# [nltk_data] Downloading package stopwords to /home/ucloud/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df.to_pickle('stopwords_removed.pkl')

# %%
df
# Out:
#                              title      tag                    artist  year
# 0                        Killa Cam      rap                   Cam'ron  2004  \
# 1                       Can I Live      rap                     JAY-Z  1996
# 2                Forgive Me Father      rap                  Fabolous  2003
# 3                     Down and Out      rap                   Cam'ron  2004
# 4                           Fly In      rap                 Lil Wayne  2005
# ...                            ...      ...                       ...   ...
# 5913399  Everything Is Alright Now      pop             Chuck Bernard  2013
# 5913401                 White Lies      pop                  ElementD  2019
# 5913403                      Ocean      pop                   Effemar  2022
# 5913406            Raise Our Hands      pop  Culture Code, Pag & Mylo  2016
# 5913409                 New Number  country         Alana Springsteen  2022
#
#                                                     lyrics       id
# 0        killa cam killa cam cam killa cam killa cam ki...        1  \
# 1        yeah hah yeah rocafella invite somethin epic k...        3
# 2        maybe cause im eatin bastards fiend grub carry...        4
# 3        ugh killa baby kanye 1970s heron flow huh yeah...        5
# 4        ask young boy gon second time around gon come ...        6
# ...                                                    ...      ...
# 5913399  everything alright oh yes baby everything alri...  7882838
# 5913401  half truth half didnt say got white lies show ...  7882840
# 5913403  dance keeping moving youre boring keep feeling...  7882842
# 5913406  purpose feels alive memory waking hazy skies c...  7882845
# 5913409  need new number one aint burned brain one dont...  7882848
#
#          lyrics_word_count
# 0                      762
# 1                      548
# 2                      574
# 3                      760
# 4                      432
# ...                    ...
# 5913399                 63
# 5913401                171
# 5913403                166
# 5913406                184
# 5913409                293
#
# [3315185 rows x 7 columns]

# %%
#preprocessing part 4

#tokenize lyrics 
nltk.download('punkt')  # download the necessary resources for tokenization

df['lyrics'] = df['lyrics'].apply(nltk.word_tokenize)
# Out:
# [nltk_data] Downloading package punkt to /home/ucloud/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
df.to_pickle('tokenized.pkl')

# %%
df
# Out:
#                              title      tag                    artist  year
# 0                        Killa Cam      rap                   Cam'ron  2004  \
# 1                       Can I Live      rap                     JAY-Z  1996
# 2                Forgive Me Father      rap                  Fabolous  2003
# 3                     Down and Out      rap                   Cam'ron  2004
# 4                           Fly In      rap                 Lil Wayne  2005
# ...                            ...      ...                       ...   ...
# 5913399  Everything Is Alright Now      pop             Chuck Bernard  2013
# 5913401                 White Lies      pop                  ElementD  2019
# 5913403                      Ocean      pop                   Effemar  2022
# 5913406            Raise Our Hands      pop  Culture Code, Pag & Mylo  2016
# 5913409                 New Number  country         Alana Springsteen  2022
#
#                                                     lyrics       id
# 0        [killa, cam, killa, cam, cam, killa, cam, kill...        1  \
# 1        [yeah, hah, yeah, rocafella, invite, somethin,...        3
# 2        [maybe, cause, im, eatin, bastards, fiend, gru...        4
# 3        [ugh, killa, baby, kanye, 1970s, heron, flow, ...        5
# 4        [ask, young, boy, gon, second, time, around, g...        6
# ...                                                    ...      ...
# 5913399  [everything, alright, oh, yes, baby, everythin...  7882838
# 5913401  [half, truth, half, didnt, say, got, white, li...  7882840
# 5913403  [dance, keeping, moving, youre, boring, keep, ...  7882842
# 5913406  [purpose, feels, alive, memory, waking, hazy, ...  7882845
# 5913409  [need, new, number, one, aint, burned, brain, ...  7882848
#
#          lyrics_word_count
# 0                      762
# 1                      548
# 2                      574
# 3                      760
# 4                      432
# ...                    ...
# 5913399                 63
# 5913401                171
# 5913403                166
# 5913406                184
# 5913409                293
#
# [3315185 rows x 7 columns]

# %%
#preprocessing part 5

from nltk.stem.snowball import SnowballStemmer

stemmer = SnowballStemmer("english")

df['stemmed_lyrics'] = df['lyrics'].apply(lambda x: [stemmer.stem(word) for word in x])

# %%
df
# Out:
#                              title      tag                    artist  year
# 0                        Killa Cam      rap                   Cam'ron  2004  \
# 1                       Can I Live      rap                     JAY-Z  1996
# 2                Forgive Me Father      rap                  Fabolous  2003
# 3                     Down and Out      rap                   Cam'ron  2004
# 4                           Fly In      rap                 Lil Wayne  2005
# ...                            ...      ...                       ...   ...
# 5913399  Everything Is Alright Now      pop             Chuck Bernard  2013
# 5913401                 White Lies      pop                  ElementD  2019
# 5913403                      Ocean      pop                   Effemar  2022
# 5913406            Raise Our Hands      pop  Culture Code, Pag & Mylo  2016
# 5913409                 New Number  country         Alana Springsteen  2022
#
#                                                     lyrics       id
# 0        [killa, cam, killa, cam, cam, killa, cam, kill...        1  \
# 1        [yeah, hah, yeah, rocafella, invite, somethin,...        3
# 2        [maybe, cause, im, eatin, bastards, fiend, gru...        4
# 3        [ugh, killa, baby, kanye, 1970s, heron, flow, ...        5
# 4        [ask, young, boy, gon, second, time, around, g...        6
# ...                                                    ...      ...
# 5913399  [everything, alright, oh, yes, baby, everythin...  7882838
# 5913401  [half, truth, half, didnt, say, got, white, li...  7882840
# 5913403  [dance, keeping, moving, youre, boring, keep, ...  7882842
# 5913406  [purpose, feels, alive, memory, waking, hazy, ...  7882845
# 5913409  [need, new, number, one, aint, burned, brain, ...  7882848
#
#          lyrics_word_count                                     stemmed_lyrics
# 0                      762  [killa, cam, killa, cam, cam, killa, cam, kill...
# 1                      548  [yeah, hah, yeah, rocafella, invit, somethin, ...
# 2                      574  [mayb, caus, im, eatin, bastard, fiend, grub, ...
# 3                      760  [ugh, killa, babi, kany, 1970s, heron, flow, h...
# 4                      432  [ask, young, boy, gon, second, time, around, g...
# ...                    ...                                                ...
# 5913399                 63  [everyth, alright, oh, yes, babi, everyth, alr...
# 5913401                171  [half, truth, half, didnt, say, got, white, li...
# 5913403                166  [danc, keep, move, your, bore, keep, feel, oce...
# 5913406                184  [purpos, feel, aliv, memori, wake, hazi, sky, ...
# 5913409                293  [need, new, number, one, aint, burn, brain, on...
#
# [3315185 rows x 8 columns]

# %%
df.to_pickle('stemmed.pkl')

# %%
from nltk.stem.wordnet import WordNetLemmatizer

nltk.download('wordnet')  # download WordNet

lemmatizer = WordNetLemmatizer()

df['lemmatized_lyrics'] = df['lyrics'].apply(lambda x: [lemmatizer.lemmatize(word) for word in x])
# Out:
# [nltk_data] Downloading package wordnet to /home/ucloud/nltk_data...

# %%
df
# Out:
#                              title      tag                    artist  year
# 0                        Killa Cam      rap                   Cam'ron  2004  \
# 1                       Can I Live      rap                     JAY-Z  1996
# 2                Forgive Me Father      rap                  Fabolous  2003
# 3                     Down and Out      rap                   Cam'ron  2004
# 4                           Fly In      rap                 Lil Wayne  2005
# ...                            ...      ...                       ...   ...
# 5913399  Everything Is Alright Now      pop             Chuck Bernard  2013
# 5913401                 White Lies      pop                  ElementD  2019
# 5913403                      Ocean      pop                   Effemar  2022
# 5913406            Raise Our Hands      pop  Culture Code, Pag & Mylo  2016
# 5913409                 New Number  country         Alana Springsteen  2022
#
#                                                     lyrics       id
# 0        [killa, cam, killa, cam, cam, killa, cam, kill...        1  \
# 1        [yeah, hah, yeah, rocafella, invite, somethin,...        3
# 2        [maybe, cause, im, eatin, bastards, fiend, gru...        4
# 3        [ugh, killa, baby, kanye, 1970s, heron, flow, ...        5
# 4        [ask, young, boy, gon, second, time, around, g...        6
# ...                                                    ...      ...
# 5913399  [everything, alright, oh, yes, baby, everythin...  7882838
# 5913401  [half, truth, half, didnt, say, got, white, li...  7882840
# 5913403  [dance, keeping, moving, youre, boring, keep, ...  7882842
# 5913406  [purpose, feels, alive, memory, waking, hazy, ...  7882845
# 5913409  [need, new, number, one, aint, burned, brain, ...  7882848
#
#          lyrics_word_count                                     stemmed_lyrics
# 0                      762  [killa, cam, killa, cam, cam, killa, cam, kill...  \
# 1                      548  [yeah, hah, yeah, rocafella, invit, somethin, ...
# 2                      574  [mayb, caus, im, eatin, bastard, fiend, grub, ...
# 3                      760  [ugh, killa, babi, kany, 1970s, heron, flow, h...
# 4                      432  [ask, young, boy, gon, second, time, around, g...
# ...                    ...                                                ...
# 5913399                 63  [everyth, alright, oh, yes, babi, everyth, alr...
# 5913401                171  [half, truth, half, didnt, say, got, white, li...
# 5913403                166  [danc, keep, move, your, bore, keep, feel, oce...
# 5913406                184  [purpos, feel, aliv, memori, wake, hazi, sky, ...
# 5913409                293  [need, new, number, one, aint, burn, brain, on...
#
#                                          lemmatized_lyrics
# 0        [killa, cam, killa, cam, cam, killa, cam, kill...
# 1        [yeah, hah, yeah, rocafella, invite, somethin,...
# 2        [maybe, cause, im, eatin, bastard, fiend, grub...
# 3        [ugh, killa, baby, kanye, 1970s, heron, flow, ...
# 4        [ask, young, boy, gon, second, time, around, g...
# ...                                                    ...
# 5913399  [everything, alright, oh, yes, baby, everythin...
# 5913401  [half, truth, half, didnt, say, got, white, li...
# 5913403  [dance, keeping, moving, youre, boring, keep, ...
# 5913406  [purpose, feel, alive, memory, waking, hazy, s...
# 5913409  [need, new, number, one, aint, burned, brain, ...
#
# [3315185 rows x 9 columns]

# %%
df.to_pickle('lemmatized.pkl')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.to_pickle('lemmatized.pkl')
#
# NameError: name 'df' is not defined
